# %% [markdown]
# # Data Types, Evaluations, Basic I/O

# %%
height_cm = input('Height converter: enter your height in cm: ')
float_height_cm=float(height_cm)
print('Your height in feet is:', float_height_cm / 30.48)
# Out:
# Your height in feet is: 5.282152230971128

# %%
height_cm = float(input('Height converter: enter your height in cm: '))
print('Your height in feet is:', height_cm / 30.48)
# Out:
# Your height in feet is: 5.282152230971128

# %%
year_born = int(input('What year were you born?'))
print('In 2100 you will be', 2100 - year_born,'years old')
# Out:
# In 2100 you will be 105 years old

# %% [markdown]
# ## More about operators

# %%
# ORDER OF OPERATORS
# 1. **
# 2. * / // %
# 3. + -

# %%
2+3*2 # = 2+(3*2)
# Out:
# 8

# %%
print(0.1)
# Out:
# 0.1

# %%
print(0.1 + 0.1 + 0.1)
# Out:
# 0.30000000000000004

# %%
2 ** 2 ** 3 # Python starts from right = right-sided binding
# Out:
# 256

# %% [markdown]
# ## More about print and strings

# %%
len('Hello') # number of characters
# Out:
# 5

# %%
print('Hello, World!')
print('Python speaking!')
# Out:
# Hello, World!
# Python speaking!

# %%
# keyword arguments / named arguments
print('Hello, World!', end='.')
print('Python speaking!')
# Out:
# Hello, World!.Pthon speaking!

# %%
first_name = 'John'
print('Your first name is', first_name, 'Welcome!', sep = '-', end='=')
# Out:
# Your first name is-John-Welcome!=

# %% [markdown]
# ## Bit operators

# %%
&
|
~
^
<<
>>
# Out:
#   Cell In[22], line 1
#     &
#     ^
# SyntaxError: invalid syntax

# %%
first_bit = 1
second_bit = 0

# %%
print(first_bit & second_bit)
# Out:
# 0

# %%
print(first_bit | second_bit)
# Out:
# 1

# %%
first_bit = 1
second_bit = 1
print(first_bit ^ second_bit)
# Out:
# 0

# %%
print(~0)
# Out:
# -1

# %%
12<<1
# Out:
# 24

# %%
12<<2
# Out:
# 48

# %%
12>>2
# Out:
# 3

# %% [markdown]
# ## Excercises

# %%
average_rating = input('Please provide your avg rating: ')
print(average_rating * 3)
# Out:
# 5.05.05.0

# %%
a = int(input('First number: '))
b = int(input('Second number: '))
 
a = a % b
b = b % a
 
print(a, b)
# Out:
# 1 0
