# %% [markdown]
# # Basic Concepts

# %%
# first program
print('Hello, World!')
# Out:
# Hello, World!

# %%
print('I\'m studying Python')
# Out:
# I'm studying Python

# %%
print('I\'m studying Python')
print()
print('and having fun')
# Out:
# I'm studying Python
#
# and having fun

# %%
print('I\'m studying Python', 'and having fun')
# Out:
# I'm studying Python and having fun

# %%
print('I\'m studying \n Python')
# Out:
# I'm studying
#  Python

# %%
print("I\'m learning to become a Python developer!\nI\'m so excited!")
# Out:
# I'm learning to become a Python developer!
# I'm so excited!

# %% [markdown]
# ## Variables

# %%
greeting = 'Hello, friend'
print(greeting)
print('greeting')
greeting = 'Hi, everybody'
print(greeting)
# Out:
# Hello, friend
# greeting
# Hi, everybody

# %%
print(new_greeting)
new_greeting = 'Cheers'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(new_greeting)
#       2 new_greeting = 'Cheers'
#
# NameError: name 'new_greeting' is not defined

# %%
_correctName
correctName
correctName89
98incorrectname
# Out:
# <>:4: SyntaxWarning: invalid decimal literal
# <>:4: SyntaxWarning: invalid decimal literal
# /var/folders/3l/7w9wdsv55yzcbs19vx4f_8k00000gq/T/ipykernel_98190/1158509853.py:4: SyntaxWarning: invalid decimal literal
#   98incorrectname
#   Cell In[23], line 4
#     98incorrectname
#       ^
# SyntaxError: invalid syntax

# %%
greeting
Greeting
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 greeting
# ----> 2 Greeting
#
# NameError: name 'Greeting' is not defined

# %%
#cannot be used as variable names
from = 'aa'
global = 'bb'
# Out:
#   Cell In[26], line 2
#     from = 'aa'
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Data Types

# %%
greeting = 'hello' #string
age = 35 #integer
age = '35' #string
speed = 4.5 #float
speed = 4 #integer
abc = True #booleans
xyz = False #booleans

# %% [markdown]
# ## Comments

# %%
print ('sample') # mid-line comment
# Out:
# sample

# %%
# all-line comment

# %%
# note that the variables are strings, not numbers
var1 = '23'
var2 = '54'

# %%
print('hello')
# print('hello2') - commenting out part of the code
# Out:
# hello

# %% [markdown]
# ## Numerical representations

# %%
# undescores in numbers
12_0_30
12030 #same value as above

# %%
# scientific notation
# 3e4 = 3E4 = 3 * 10000 = 3000
# 3e-4 = 3E-4 = 3 * 1/10000 = 0.0003
print(0.0000000000000000000000000003)
# Out:
# 3e-28

# %%
# octal numbers
# start with 0O or 0o
print(0o123) # 83

# hexadecimal numbers
# start with 0X or 0x
print(0x123) # 291
# Out:
# 83
# 291

# %% [markdown]
# ## Operatos

# %%
2+3
# Out:
# 5

# %%
5-4
# Out:
# 1

# %%
3*5
# Out:
# 15

# %%
# standard division
6/2  # always produces float number
# Out:
# 3.0

# %%
# integer division
6 // 2 # always produces nearest whole number rounded down
# Out:
# 3

# %%
# modulus division
6 % 2 # returns the remainder of the division
# Out:
# 0

# %%
7%2
# Out:
# 1

# %%
7//2
# Out:
# 3

# %%
7 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 7 / 0
#
# ZeroDivisionError: division by zero

# %%
# power operator
2**3 # = 2*2*2
# Out:
# 8

# %%
2+3
# Out:
# 5

# %%
2+3.0 # returns float
# Out:
# 5.0

# %%
2.0+3.0 # return float
# Out:
# 5.0

# %% [markdown]
# ## Reassigning values

# %%
age = 28
print(age)
# Out:
# 28

# %%
age = 28
new_age = age + 5
print(new_age)
# Out:
# 33

# %%
age = 28
age = age + 7
print (age)
# Out:
# 35

# %%
age = 28
age +=7
print(age)
# Out:
# 35

# %%
age *=2
print(age)
# Out:
# 140

# %%
age -=5
print(age)
# Out:
# 135

# %%
age /=3
print(age)
# Out:
# 45.0

# %%
text = 'hokus'+'pokus'
print(text)
# Out:
# hokuspokus

# %%
print('hokus'*3)
# Out:
# hokushokushokus

# %%
print(23+5)
# Out:
# 28

# %%
print('23'+'5')
# Out:
# 235

# %% [markdown]
# ## Input function

# %%
input('What is your name?')
user_name = input()
print('Hello,', user_name)
# Out:
# Hello, Lucie

# %% [markdown]
# ## Excercises

# %%
print('Let it' + 'snow')
print('And', 'snow')
# Out:
# Let itsnow
# And snow

# %%
a = '2'
b = '3'
print (a + b)
# Out:
# 23
